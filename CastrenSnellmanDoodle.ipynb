# %%
import requests
from bs4 import BeautifulSoup

# %%
# Generates links to pdfs featured on https://www.panynj.gov/airports/en/statistics-general-info.html
years = [2020, 2021, 2022]
months = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
for year in years:
  for month in months:    
    url = f'https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-{year}/JFK_{month}_{year}.pdf'
    print(url)
# Out:
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_JAN_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_FEB_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_MAR_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_APR_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_MAY_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_JUN_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_JUL_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_AUG_2020.pdf
# https://www.panynj.gov/content/dam/airports/statistics/statistics-general-info/monthly-2020/JFK_SEP_2020.pdf
# ...

# %%
print(raw_html)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n        <title>People</title>\r\n    <meta content="People,Find lawyer,lawyer,assistant,internal business services" name="keywords" />\r\n<meta content="Castren &amp; Snellman" property="og:site_name" />\r\n<meta content="People" property="og:title" />\r\n<meta content="website" property="og:type" />\r\n<meta content="https://www.castren.fi/people/" property="og:url" />\r\n<meta content="Find the right lawyer for your any situation. Search by name." name="description" property="og:description" />\r\n<meta content="https://www.castren.fi/4aaa4a/globalassets/people/people_jussi_teaser.jpg" property="og:image" />\r\n\r\n    <link href="/people/" rel="canonical" />\r\n    <link href="/people/" hreflang="en" rel="alternate" /><link href="/fi/ihmiset/" hreflang="f
# ...

# %%
soup_doc = BeautifulSoup(raw_html, "html.parser")
print(type(soup_doc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    People
#   </title>
#   <meta content="People,Find lawyer,lawyer,assistant,internal business services" name="keywords"/>
#   <meta content="Castren &amp; Snellman" property="og:site_name"/>
#   <meta content="People" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.castren.fi/people/" property="og:url"/>
#   <meta content="Find the right lawyer for your any situation. Search by name." name="description" property="og:description"/>
#   <meta content="https://www.castren.fi/4aaa4a/globalassets/people/people_jussi_teaser.jpg" property="og:image"/>
#   <link href="/people/" rel="canonical"/>
#   <link href="/people/" hreflang="en" rel="alternate"/>
#   <link href="/fi/ihmiset/" hreflang="fi" rel="alternate"/>
# ...

# %%
soup_doc.select("div.title")
# Out:
# [<div class="title" ng-bind="result.roleTitle"></div>,
#  <div class="title">{{result.roleTitle}}</div>]
